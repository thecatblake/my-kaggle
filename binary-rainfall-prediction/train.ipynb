# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import wandb
from wandb.integration.xgboost import WandbCallback

import numpy as np
import xgboost as xgb
import pandas as pd

# %%
data = pd.read_csv("train.csv", header=0, index_col=0)

train_x, test_x, train_y, test_y = train_test_split(data.drop("rainfall", axis=1), data["rainfall"], test_size=0.2, random_state=42)

# %%
test_x
# Out:
#       day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# id
# 289   290    1014.9     26.3         23.3     20.1      17.4      75.0   83.0
# 1692  233    1009.5     31.0         29.8     28.2      24.5      78.0   78.0
# 1590  131    1012.2     31.9         29.9     28.3      24.9      75.0   72.0
# 383    19    1034.6     11.2         10.4      7.0       3.4      77.0   95.0
# 1818  359    1017.5     17.5         16.4     15.8      15.9      85.0   91.0
# ...   ...       ...      ...          ...      ...       ...       ...    ...
# 2073  249    1011.5     30.5         27.4     25.5      23.8      76.0   53.0
# 744    15    1019.9     20.6         17.2     16.1      15.9      97.0   99.0
# 879   150    1006.7     34.1         30.1     26.8      25.2      81.0   80.0
# 1978  154    1009.3     33.8         30.3     29.3      26.3      78.0   78.0
# 1170   76    1013.3     25.9         23.1     21.5      21.4      91.0   88.0
#
#       sunshine  winddirection  windspeed
# id
# 289        3.0           40.0       22.0
# 1692       7.7          220.0       26.4
# 1590       8.4          180.0        8.0
# 383        0.0           40.0       16.0
# 1818       1.5           50.0       19.0
# ...        ...            ...        ...
# 2073      10.1           50.0       28.6
# 744        0.0           40.0       20.4
# 879        3.9          200.0       24.4
# 1978       7.4          200.0        9.8
# 1170       1.4           50.0       33.2
#
# [438 rows x 11 columns]

# %%
train.drop(columns=["rainfall"])
# Out:
#       day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# id
# 0       1    1017.4     21.2         20.6     19.9      19.4      87.0   88.0
# 1       2    1019.5     16.2         16.9     15.8      15.4      95.0   91.0
# 2       3    1024.1     19.4         16.1     14.6       9.3      75.0   47.0
# 3       4    1013.4     18.1         17.8     16.9      16.8      95.0   95.0
# 4       5    1021.8     21.3         18.4     15.2       9.6      52.0   45.0
# ...   ...       ...      ...          ...      ...       ...       ...    ...
# 2185  361    1014.6     23.2         20.6     19.1      19.9      97.0   88.0
# 2186  362    1012.4     17.2         17.3     16.3      15.3      91.0   88.0
# 2187  363    1013.3     19.0         16.3     14.3      12.6      79.0   79.0
# 2188  364    1022.3     16.4         15.2     13.8      14.7      92.0   93.0
# 2189  365    1013.8     21.2         19.1     18.0      18.0      89.0   88.0
#
#       sunshine  winddirection  windspeed
# id
# 0          1.1           60.0       17.2
# 1          0.0           50.0       21.9
# 2          8.3           70.0       18.1
# 3          0.0           60.0       35.6
# 4          3.6           40.0       24.8
# ...        ...            ...        ...
# 2185       0.1           40.0       22.1
# 2186       0.0           50.0       35.3
# 2187       5.0           40.0       32.9
# 2188       0.1           40.0       18.0
# 2189       1.0           70.0       48.0
#
# [2190 rows x 11 columns]

# %%
model.fit(train.drop("rainfall", axis=1), train["rainfall"])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.1, eval_metric=None,
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, nthread=4, ...)
